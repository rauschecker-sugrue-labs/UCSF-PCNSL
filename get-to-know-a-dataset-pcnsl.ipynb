# %% [markdown]
# # Get to Know a Dataset: PCNSL (Primary CNS Lymphoma) MRI Dataset
#
# This notebook serves as a guided tour of the [PCNSL MRI Dataset](https://registry.opendata.aws/ucsf-pcnsl) dataset. More usage examples, tutorials, and documentation for this dataset and others can be found at the [Registry of Open Data on AWS](https://registry.opendata.aws/).

# %% [markdown]
# ### Q: How have you organized your dataset? Help us understand the key prefix structure of your S3 bucket.
#
# Our dataset is organized in BIDS (Brain Imaging Data Structure) format. The structure contains a `derivatives/pyalfe/` folder with processed outputs for each subject and session:
#
# ```
# s3://ucsf-pcnsl/
# └── derivatives/pyalfe/
#     └── sub-XXXX/ses-YYYY/
#         ├── dicom_headers/             # MRI acquisition parameters (JSON, one per sequence)
#         ├── statistics/
#         │   ├── lesions_SummaryLesions/    # Aggregate lesion statistics (CSV)
#         │   ├── lesions_IndividualLesions/ # Per-lesion measurements (CSV)
#         │   └── lesions_radiomics/        # PyRadiomics texture features (CSV)
#         ├── skullstripped/
#         │   ├── lesions_FLAIR_space/      # Brain-extracted images in FLAIR space
#         │   └── lesions_T1Post_space/     # Brain-extracted images in T1 post-contrast space
#         └── masks/
#             └── lesions_seg_comp/         # Lesion segmentation masks
# ```
#
# Full documentation for this dataset can be found in the dataset's README and associated publications.

# %%
# This notebook requires Python 3.10-3.13 and the following libraries
# (please install using the preferred method for your environment, e.g. pip, conda, uv):
#
# nibabel >= 5.0
# nilearn >= 0.10
# pandas >= 2.0
# numpy >= 1.24
# matplotlib >= 3.7
#
# Or install all dependencies with: uv sync

# %% [markdown]
# First we will import the Python libraries required throughout this notebook.

# %%
# Import the libraries required for this notebook
import json
from pathlib import Path

import nibabel as nib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nilearn import plotting

# For Jupyter notebooks, try to use inline backend
try:
    from IPython import get_ipython
    if get_ipython() is not None:
        get_ipython().run_line_magic('matplotlib', 'inline')
except:
    pass

print("All imports successful!")
# Out:
# All imports successful!

# %% [markdown]
# ## Data Paths Configuration
#
# Set `BIDS_DIR` to the root of your local BIDS dataset before running the cells below.

# %%
# =============================================================================
# DATA PATHS CONFIGURATION
# =============================================================================
BIDS_DIR = Path("/Users/mromano/Library/CloudStorage/Box-Box/Research/pcnsl_radiomics/dataset_manuscript/bids_dir_for_aws_anon")

# List subjects from the derivatives directory
subjects = sorted([
    d.name for d in (BIDS_DIR / "derivatives" / "pyalfe").iterdir()
    if d.is_dir() and d.name.startswith("sub-")
])
print(f"Found {len(subjects)} subjects:")
for subj in subjects[:10]:
    print(f"  {subj}/")
if len(subjects) > 10:
    print(f"  ... and {len(subjects) - 10} more subjects")
# Out:
# Found 150 subjects:
#   sub-0001/
#   sub-0002/
#   sub-0003/
#   sub-0004/
#   sub-0005/
#   sub-0006/
#   sub-0007/
#   sub-0008/
#   sub-0009/
#   sub-0010/
#   ... and 140 more subjects

# %% [markdown]
# The derivatives folder for each subject/session contains segmentation masks, skull-stripped registered images, and lesion statistics.

# %%
# Show derivatives structure for a subject
subject = "sub-0001"
session = "ses-0001"

deriv_path = BIDS_DIR / "derivatives" / "pyalfe" / subject / session
print(f"Derivatives for {subject}/{session}:")
for item in sorted(deriv_path.iterdir()):
    if item.is_dir():
        print(f"  {item.name}/")
        for subitem in sorted(item.iterdir()):
            print(f"    {subitem.name}/")
# Out:
# Derivatives for sub-0001/ses-0001:
#   dicom_headers/
#     sub-0001_ses-0001_DWI_ADC.json/
#     sub-0001_ses-0001_FLAIR.json/
#     sub-0001_ses-0001_T1w.json/
#     sub-0001_ses-0001_ce-gadolinium_T1w.json/
#   masks/
#     lesions_seg_comp/
#   skullstripped/
#     lesions_FLAIR_space/
#     lesions_T1Post_space/
#   statistics/
#     lesions_IndividualLesions/
#     lesions_SummaryLesions/
#     lesions_radiomics/

# %% [markdown]
# ### Q: What data formats are present in your dataset? What kinds of data are stored using these formats? Can you give any advice for how you work with these data formats?
#
# Our dataset contains three primary data formats:
#
# **1. NIfTI (Neuroimaging Informatics Technology Initiative) - `.nii.gz` files**
#
# NIfTI is the standard format for neuroimaging data. Our dataset uses NIfTI for:
# - Skull-stripped (brain-extracted) images registered to FLAIR and T1 post-contrast space
# - Lesion segmentation masks
#
# NIfTI files store:
# - 3D volumetric image data as a multidimensional array
# - Header information including voxel dimensions, orientation, and coordinate system
# - Affine transformation matrix for mapping voxel to world coordinates
#
# We recommend using:
# - **nibabel**: Python library for reading/writing NIfTI files
# - **nilearn**: Built on nibabel, provides neuroimaging-specific visualization and analysis tools
# - **ITK-SNAP** or **3D Slicer**: Desktop applications for interactive visualization
#
# **2. JSON - `.json` files (DICOM headers)**
#
# Each subject/session includes one JSON file per MRI sequence in `dicom_headers/`, containing acquisition parameters derived from the original DICOM files:
# - Scanner manufacturer and model
# - Magnetic field strength
# - Sequence parameters (TR, TE, flip angle, slice thickness, etc.)
# - Acquisition and reconstruction matrix sizes
#
# These files follow the BIDS sidecar convention and can be read with Python's built-in `json` module.
#
# **3. CSV (Comma-Separated Values) - `.csv` files**
#
# CSV files contain quantitative measurements extracted from the images:
# - **SummaryLesions**: Aggregate lesion statistics per subject (total volume, tissue distribution)
# - **IndividualLesions**: Per-lesion measurements (one row per lesion)
# - **radiomics**: PyRadiomics texture features for machine learning applications
#
# Microsoft Excel, the python Pandas library, and the Polars library among others can all be used to explore CSVs.

# %% [markdown]
# ### Q: Can you show us an example of downloading and loading data from your dataset?
#
# Let's load a skull-stripped FLAIR image and its associated lesion statistics.

# %%
# Helper functions to load data from the local filesystem

def load_nifti(key):
    """Load a NIfTI file from the BIDS directory."""
    local_path = BIDS_DIR / key
    print(f"Loading: {local_path.name}")
    return nib.load(local_path)

def load_csv(key):
    """Load a CSV file from the BIDS directory."""
    local_path = BIDS_DIR / key
    print(f"Loading: {local_path.name}")
    return pd.read_csv(local_path)

# Load the skull-stripped FLAIR image (registered to FLAIR space) for sub-0001
subject = "sub-0001"
session = "ses-0001"
flair_ss_key = f"derivatives/pyalfe/{subject}/{session}/skullstripped/lesions_FLAIR_space/{subject}_{session}_FLAIR_to_FLAIR_skullstripped.nii.gz"

flair_ss = load_nifti(flair_ss_key)
print(f"\nSkull-stripped FLAIR loaded successfully!")
# Out:
# Loading: sub-0001_ses-0001_FLAIR_to_FLAIR_skullstripped.nii.gz
#
# Skull-stripped FLAIR loaded successfully!

# %% [markdown]
# Let's examine the properties of the loaded skull-stripped FLAIR NIfTI image.

# %%
# Display image properties
print(f"Image shape: {flair_ss.shape}")
print(f"Voxel dimensions (mm): {flair_ss.header.get_zooms()}")
print(f"Data type: {flair_ss.get_data_dtype()}")
print(f"Affine matrix:\n{flair_ss.affine}")
# Out:
# Image shape: (512, 336, 512)
# Voxel dimensions (mm): (np.float32(0.5), np.float32(0.6999674), np.float32(0.5))
# Data type: float32
# Affine matrix:
# [[ 4.99767482e-01  6.59675756e-03 -1.45006021e-02 -1.17457367e+02]
#  [-5.77664934e-03  6.97994173e-01 -3.70694548e-02 -7.21293335e+01]
#  [ 1.41103491e-02  5.21052182e-02  4.98413056e-01 -1.57219482e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]

# %% [markdown]
# Now let's load the lesion statistics CSV file.

# %%
# Load summary lesion statistics
stats_key = f"derivatives/pyalfe/{subject}/{session}/statistics/lesions_SummaryLesions/{subject}_{session}_FLAIR_SummaryLesions.csv"

summary_stats = load_csv(stats_key)

print(f"\nSummary statistics columns:")
print(summary_stats.columns.tolist())
print(f"\nStatistics for {subject}:")
summary_stats
# Out:
# Loading: sub-0001_ses-0001_FLAIR_SummaryLesions.csv
#
# Summary statistics columns:
# ['Label', 'Value']
#
# Statistics for sub-0001:
#                                     Label         Value
# 0                     total_lesion_volume  73343.984375
# 1             lesion_volume_in_background     73.671567
# 2                    lesion_volume_in_csf   2187.748060
# 3   lesion_volume_in_cortical_gray_matter  24346.440554
# 4           lesion_volume_in_white_matter  36406.003627
# ..                                    ...           ...
# 59            lesion_volume_in_Cerebellum      0.000000
# 60        percentage_volume_in_Cerebellum      0.000000
# 61                      number_of_lesions      1.000000
# 62                  largest_lesion_volume  73343.984375
# 63                  average_lesion_volume  73343.984375
#
# [64 rows x 2 columns]

# %% [markdown]
# ### DICOM Header Data
#
# Each subject/session contains a `dicom_headers/` folder with one JSON file per MRI sequence. These capture acquisition parameters (scanner model, field strength, TR/TE, slice thickness, etc.) derived from the original DICOM files.

# %%
from pcnsl_data_loader import parse_dicom_tag_json

# Load DICOM headers for a single subject/session
dicom_dir = BIDS_DIR / "derivatives" / "pyalfe" / subject / session / "dicom_headers"

dicom_headers = {}
for json_file in sorted(dicom_dir.glob("*.json")):
    sequence = "_".join(json_file.stem.split("_")[2:])
    dicom_headers[sequence] = parse_dicom_tag_json(json_file)

print(f"Sequences with DICOM headers: {list(dicom_headers.keys())}")

# Show key acquisition parameters for the FLAIR sequence
key_fields = [
    "Manufacturer", "ManufacturerModelName", "MagneticFieldStrength",
    "MRAcquisitionType", "RepetitionTime", "EchoTime", "InversionTime",
    "FlipAngle", "SliceThickness", "Matrix", "FOV_row_mm", "FOV_col_mm", "NumSlices",
]
print(f"
FLAIR acquisition parameters:")
flair_hdr = dicom_headers.get("FLAIR", {})
for key in key_fields:
    val = flair_hdr.get(key, "N/A")
    unit = " ms" if key in ("RepetitionTime", "EchoTime", "InversionTime") else ""
    print(f"  {key}: {val}{unit}")
# Out:
# Sequences with DICOM headers: ['DWI_ADC', 'FLAIR', 'T1w', 'ce-gadolinium_T1w']
#
# FLAIR acquisition parameters:
#   Manufacturer: GE
#   ManufacturersModelName: Signa HDxt
#   MagneticFieldStrength: 1.5
#   MRAcquisitionType: 3D
#   RepetitionTime: 5.8
#   EchoTime: 0.146656
#   InversionTime: 1.776
#   FlipAngle: 90
#   SliceThickness: 1.4
#   ReconMatrixPE: 512
#   AcquisitionMatrixPE: 256

# %% [markdown]
# Now let's aggregate DICOM headers across the full cohort to characterize scanner and acquisition variability — a common first step when working with a multi-site dataset.

# %%
from pcnsl_data_loader import load_aws_dicom_headers

# Aggregate DICOM headers across all subjects
dicom_df = load_aws_dicom_headers()

print(f"Loaded {len(dicom_df)} records across {dicom_df['subject'].nunique()} subjects")
print(f"Sequences: {dicom_df['sequence'].value_counts().to_dict()}")

flair_df = dicom_df[dicom_df["sequence"] == "FLAIR"]
print(f"
Manufacturer distribution (FLAIR):")
print(flair_df["Manufacturer"].value_counts().to_string())
print(f"
Field strength distribution (FLAIR, T):")
print(flair_df["MagneticFieldStrength"].value_counts().sort_index().to_string())
print(f"
Matrix distribution (FLAIR):")
print(flair_df["Matrix"].value_counts().to_string())
# Out:
# Loaded 600 records across 150 subjects
# Sequences: {'DWI_ADC': 150, 'FLAIR': 150, 'T1w': 150, 'ce-gadolinium_T1w': 150}
#
# Manufacturer distribution (FLAIR):
# Manufacturer
# GE         132
# Siemens     13
# Philips      5
#
# Field strength distribution (FLAIR):
# MagneticFieldStrength
# 1.5    51
# 3.0    99

# %%
# Visualize scanner and acquisition parameter variability across the cohort
fig, axes = plt.subplots(1, 3, figsize=(14, 5), facecolor='white')

flair_df = dicom_df[dicom_df["sequence"] == "FLAIR"].copy()

# Panel 1: Manufacturer distribution
mfr_counts = flair_df["Manufacturer"].value_counts()
axes[0].bar(mfr_counts.index, mfr_counts.values, color='#3498db', edgecolor='white', linewidth=1.2)
axes[0].set_title('Scanner Manufacturer', fontsize=13, fontweight='bold', pad=10)
axes[0].set_ylabel('Number of Subjects', fontsize=11)
axes[0].tick_params(axis='x', rotation=30)
axes[0].set_facecolor('#f8f9fa')
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)

# Panel 2: Field strength distribution
fs_counts = flair_df["MagneticFieldStrength"].value_counts().sort_index()
axes[1].bar([f"{v}T" for v in fs_counts.index], fs_counts.values,
            color='#e67e22', edgecolor='white', linewidth=1.2)
axes[1].set_title('Field Strength', fontsize=13, fontweight='bold', pad=10)
axes[1].set_ylabel('Number of Subjects', fontsize=11)
axes[1].set_facecolor('#f8f9fa')
axes[1].spines['top'].set_visible(False)
axes[1].spines['right'].set_visible(False)

# Panel 3: FLAIR TR distribution (ms, native DICOM units)
tr_vals = pd.to_numeric(flair_df["RepetitionTime"], errors="coerce").dropna()
axes[2].hist(tr_vals, bins=20, color='#2ecc71', edgecolor='white', linewidth=1.2)
axes[2].set_title('FLAIR Repetition Time (TR)', fontsize=13, fontweight='bold', pad=10)
axes[2].set_xlabel('TR (ms)', fontsize=11)
axes[2].set_ylabel('Number of Subjects', fontsize=11)
axes[2].set_facecolor('#f8f9fa')
axes[2].spines['top'].set_visible(False)
axes[2].spines['right'].set_visible(False)

plt.suptitle('Scanner and Acquisition Variability Across PCNSL Cohort',
             fontsize=15, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# Summary table: key parameters by sequence
print("
Acquisition parameter summary (mean ± SD):")
param_cols = {
    "RepetitionTime":  "TR (ms)",
    "EchoTime":        "TE (ms)",
    "SliceThickness":  "Slice Thickness (mm)",
    "FOV_row_mm":      "FOV row (mm)",
    "FOV_col_mm":      "FOV col (mm)",
    "NumSlices":       "Num Slices",
}
seq_order = ["FLAIR", "T1w", "ce-gadolinium_T1w", "DWI_ADC"]

rows = []
for seq in seq_order:
    sub = dicom_df[dicom_df["sequence"] == seq]
    row = {"Sequence": seq}
    matrix_vals = sub["Matrix"].dropna() if "Matrix" in sub.columns else pd.Series(dtype=str)
    row["Matrix"] = matrix_vals.mode().iloc[0] if len(matrix_vals) else "—"
    for col, label in param_cols.items():
        vals = pd.to_numeric(sub[col], errors="coerce").dropna() if col in sub.columns else pd.Series(dtype=float)
        row[label] = f"{vals.mean():.1f} ± {vals.std():.1f}" if len(vals) else "—"
    rows.append(row)

pd.DataFrame(rows).set_index("Sequence")
# Out:
# Acquisition parameter summary (mean ± SD):
#                            TR (ms)       TE (ms) Slice Thickness (mm)
# Sequence
# FLAIR              6997.4 ± 1541.5  125.4 ± 30.5            2.4 ± 1.6
# T1w                  530.3 ± 736.2     6.8 ± 5.2            3.0 ± 1.8
# ce-gadolinium_T1w    428.5 ± 862.2     4.4 ± 4.0            1.7 ± 1.1
# DWI_ADC            8528.8 ± 1876.7   73.0 ± 15.6            3.1 ± 1.2

# %% [markdown]
# ### Q: A picture is worth a thousand words. Show us a visual (or several!) from your dataset that either illustrates something informative about your dataset, or that you think might excite someone to dig in further.
#
# Let's visualize the MRI images and lesion segmentations from our dataset.

# %%
# Visualize the skull-stripped FLAIR image using nilearn
plotting.plot_anat(flair_ss, title=f"{subject} Skull-Stripped FLAIR Image", display_mode='ortho')
plt.show()

# %%
# Load the lesion segmentation mask (FLAIR space)
mask_key = f"derivatives/pyalfe/{subject}/{session}/masks/lesions_seg_comp/{subject}_{session}_FLAIR_abnormal_seg_comp.nii.gz"
lesion_mask = load_nifti(mask_key)

print(f"Skull-stripped FLAIR shape: {flair_ss.shape}")
print(f"Lesion mask shape: {lesion_mask.shape}")
# Out:
# Loading: sub-0001_ses-0001_FLAIR_abnormal_seg_comp.nii.gz
# Skull-stripped FLAIR shape: (512, 336, 512)
# Lesion mask shape: (512, 336, 512)

# %%
# Overlay lesion segmentation on the FLAIR image
# Note: The mask contains component labels (each lesion has a unique ID)
# Binarize for uniform color display
binary_mask = nib.Nifti1Image(
    (lesion_mask.get_fdata() > 0).astype(float), 
    lesion_mask.affine, 
    lesion_mask.header
)

plotting.plot_roi(
    binary_mask,
    bg_img=flair_ss,
    title=f"{subject} FLAIR with Lesion Overlay",
    display_mode='ortho',
    alpha=0.5,
    cmap="Reds",
    resampling_interpolation='nearest',
    vmin=0,
    vmax=1
)
plt.show()

# %%
# Mosaic view showing multiple slices
plotting.plot_roi(
    lesion_mask,
    bg_img=flair_ss,
    title=f"{subject} FLAIR Lesions (Mosaic View)",
    display_mode='mosaic',
    cut_coords=8,
    alpha=0.5,
    cmap='Reds',
    resampling_interpolation='nearest',
    vmin=0,
    vmax=1
)
plt.show()

# %%
# Load and aggregate statistics for multiple subjects to show distribution

def load_all_summary_stats(bids_dir, max_subjects=50):
    """Load summary statistics for multiple subjects from the derivatives directory."""
    all_stats = []
    pyalfe_dir = bids_dir / "derivatives" / "pyalfe"
    subjects = sorted([
        d.name for d in pyalfe_dir.iterdir()
        if d.is_dir() and d.name.startswith("sub-")
    ])

    for subj in subjects[:max_subjects]:
        try:
            stats_path = (
                pyalfe_dir / subj / "ses-0001" / "statistics"
                / "lesions_SummaryLesions" / f"{subj}_ses-0001_FLAIR_SummaryLesions.csv"
            )
            if stats_path.exists():
                df = pd.read_csv(stats_path)
                df["subject"] = subj
                all_stats.append(df)
        except Exception:
            continue

    return pd.concat(all_stats, ignore_index=True) if all_stats else pd.DataFrame()

print("Loading statistics for multiple subjects...")
all_summary = load_all_summary_stats(BIDS_DIR)

# convert to wide form
all_summary = all_summary.pivot(index="subject", columns="Unnamed: 0", values="0")

print(f"Loaded statistics for {len(all_summary)} subjects")
# Out:
# Loading statistics for multiple subjects...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/research/UCSF-PCNSL/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'Unnamed: 0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 31
#      27 print("Loading statistics for multiple subjects...")
#      28 all_summary = load_all_summary_stats(BIDS_DIR)
#      29
#      30 # convert to wide form
# ---> 31 all_summary = all_summary.pivot(index="subject", columns="Unnamed: 0", values="0")
#      32
#      33 print(f"Loaded statistics for {len(all_summary)} subjects")
#
# File ~/research/UCSF-PCNSL/.venv/lib/python3.13/site-packages/pandas/core/frame.py:10970, in DataFrame.pivot(self, columns, index, values)
#   10966         self, *, columns, index=lib.no_default, values=lib.no_default
#   10967     ) -> DataFrame:
#   10968         from pandas.core.reshape.pivot import pivot
#   10969
# > 10970         return pivot(self, index=index, columns=columns, values=values)
#
# File ~/research/UCSF-PCNSL/.venv/lib/python3.13/site-packages/pandas/core/reshape/pivot.py:893, in pivot(data, columns, index, values)
#     890 else:
#     891     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
# --> 893 data_columns = [data[col] for col in columns_listlike]
#     894 index_list.extend(data_columns)
#     895 multiindex = MultiIndex.from_arrays(index_list)
#
# File ~/research/UCSF-PCNSL/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~/research/UCSF-PCNSL/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'Unnamed: 0'

# %%
# Plot the distribution of lesion volumes
if 'total_lesion_volume' in all_summary.columns and len(all_summary) > 0:
    plt.figure(figsize=(12, 7), dpi=100, facecolor='white')
    
    plt.hist(all_summary['total_lesion_volume'], 
             bins=30,
             color='#3498db',
             edgecolor='white',
             linewidth=1.2,
             alpha=0.8)
    
    plt.title('Distribution of Total Lesion Volume in PCNSL Patients', 
             fontsize=16, pad=20, fontweight='bold')
    plt.xlabel('Total Lesion Volume (mm³)', fontsize=12, labelpad=10)
    plt.ylabel('Number of Subjects', fontsize=12, labelpad=10)
    
    plt.grid(True, linestyle='--', alpha=0.3, color='gray')
    
    ax = plt.gca()
    ax.set_facecolor('#f8f9fa')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(0.5)
    ax.spines['bottom'].set_linewidth(0.5)
    
    plt.tight_layout()
    plt.show()
    
    # Print summary statistics
    print(f"\nLesion Volume Statistics:")
    print(f"  Mean: {all_summary['total_lesion_volume'].mean():.2f} mm³")
    print(f"  Median: {all_summary['total_lesion_volume'].median():.2f} mm³")
    print(f"  Min: {all_summary['total_lesion_volume'].min():.2f} mm³")
    print(f"  Max: {all_summary['total_lesion_volume'].max():.2f} mm³")

# %%
# Box plot showing lesion distribution by tissue type
tissue_cols = [
    'lesion_volume_in_white_matter',
    'lesion_volume_in_Cortical Gray Matter',
    'lesion_volume_in_Deep Gray Matter',
    'lesion_volume_in_CorpusCallosum'
]

available_cols = [c for c in tissue_cols if c in all_summary.columns]

if available_cols and len(all_summary) > 0:
    plt.figure(figsize=(12, 7), dpi=100, facecolor='white')
    
    tissue_data = all_summary[available_cols].copy()
    tissue_data.columns = ['White Matter', 'Cortical GM', 'Deep GM', 'Corpus Callosum'][:len(available_cols)]
    
    tissue_data.boxplot()
    
    plt.title('PCNSL Lesion Volume by Brain Tissue Type', 
             fontsize=16, pad=20, fontweight='bold')
    plt.ylabel('Lesion Volume (mm³)', fontsize=12, labelpad=10)
    plt.xlabel('Tissue Type', fontsize=12, labelpad=10)
    
    plt.xticks(rotation=45)
    plt.grid(True, linestyle='--', alpha=0.3, color='gray', axis='y')
    
    ax = plt.gca()
    ax.set_facecolor('#f8f9fa')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    plt.tight_layout()
    plt.show()

# %%
# Custom visualization comparing FLAIR lesions
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Get data arrays
flair_data = flair_ss.get_fdata()
mask_data = lesion_mask.get_fdata()

# Find slice with most lesions
lesion_counts = mask_data.sum(axis=(0, 1))
best_slice = np.argmax(lesion_counts)

# FLAIR image
axes[0].imshow(np.rot90(flair_data[:, :, best_slice]), cmap='gray')
axes[0].set_title('FLAIR Image', fontsize=14)
axes[0].axis('off')

# Lesion mask
axes[1].imshow(np.rot90(mask_data[:, :, best_slice]), cmap='hot')
axes[1].set_title('Lesion Segmentation', fontsize=14)
axes[1].axis('off')

# Overlay
axes[2].imshow(np.rot90(flair_data[:, :, best_slice]), cmap='gray')
masked = np.ma.masked_where(mask_data[:, :, best_slice] == 0, 
                            mask_data[:, :, best_slice])
axes[2].imshow(np.rot90(masked), cmap='hot', alpha=0.6)
axes[2].set_title('FLAIR with Lesion Overlay', fontsize=14)
axes[2].axis('off')

plt.suptitle(f'{subject} PCNSL Lesion Visualization', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q: What is one question that you have answered using these data? Can you show us how you came to that answer?
#
# **Question: What is the typical lesion burden and anatomical distribution in primary CNS lymphoma patients?**
#
# Using this dataset, we analyzed the distribution of lesion volumes across different brain tissue types. PCNSL has a characteristic predilection for white matter, and this dataset allowed us to quantify this pattern across a cohort of patients.
#
# Key findings from our analysis:
# 1. PCNSL lesions show significant involvement of white matter
# 2. Total lesion volume varies considerably between patients, reflecting the heterogeneous nature of the disease

# %% [markdown]
# ### Q: What is one unanswered question that you think could be answered using these data? Do you have any recommendations or advice for someone wanting to answer this question?
#
# **Unanswered Question: Do radiomic features correlate with certain genomic differences in PCNSL patients?**
#
# This dataset includes PyRadiomics texture features extracted from both FLAIR and T1-Post contrast images. These features capture subtle patterns in image intensity and texture that may correlate with tumor biology and treatment outcomes.
#
# **Recommendations for tackling this question:**
#
# 1. **Data Loading**: Use the radiomics CSV files in `derivatives/pyalfe/sub-XXXX/ses-YYYY/statistics/`. Use the UCSF500 CSV file in `ucsf500_mutations.csv`
#
# 2. **Feature Selection for radiomics**: The radiomics files contain hundreds of features.
#    - Correlation-based feature selection to remove redundant features
#    - LASSO or elastic net regularization for automatic selection
#    - Domain knowledge to focus on clinically relevant feature categories
#
# 3. **Start small when looking at genetic data**:
#    - Begin by looking at the `gene` column in the UCSF500 dataset and selecting a single mutation to investigate at a time
#
# 4. **Modeling Approach**:
#    - Start with interpretable models (logistic regression, random forest)
#    - Use proper cross-validation given the relatively small sample size
#    - Consider combining FLAIR and T1-Post features for multimodal analysis
#
# 5. **Validation**: External validation on an independent cohort would strengthen any predictive model
#
# This research direction could contribute to personalized treatment planning in PCNSL.

# %% [markdown]
# ---
#
# ## Summary
#
# This tutorial covered:
#
# 1. **Dataset Organization**: BIDS-formatted derivatives with subjects, sessions, and processed outputs
# 2. **Data Formats**: NIfTI files for skull-stripped images and lesion masks, CSV files for lesion statistics
# 3. **Loading Data**: Direct filesystem access using nibabel and pandas
# 4. **Visualization**: Using nilearn and matplotlib to display skull-stripped MRI images and lesion overlays
# 5. **Analysis Examples**: Lesion volume distributions and tissue-specific patterns
#
# ### Key Resources
#
# - **nibabel documentation**: https://nipy.org/nibabel/
# - **nilearn documentation**: https://nilearn.github.io/
# - **BIDS specification**: https://bids-specification.readthedocs.io/
# - **PyRadiomics**: https://pyradiomics.readthedocs.io/
